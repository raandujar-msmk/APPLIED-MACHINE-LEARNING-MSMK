# %% [markdown]
# <a href="https://colab.research.google.com/github/raandujar-msmk/APPLIED-MACHINE-LEARNING-MSMK/blob/main/Sesion%207%20-%20LLMs/L3_pair_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pair Programming Scenarios

# %% [markdown]
# #### CREDITS
# https://learn.deeplearning.ai/courses/pair-programming-llm/lesson/m9qkc/pair-programing-scenarios

# %%
from google.colab import userdata

# %%
# Gemini API
import os
import google.generativeai as genai
from google.api_core import client_options as client_options_lib

genai.configure(
    api_key=userdata.get('GOOGLE_API_KEY'),
    transport="rest",
    client_options=client_options_lib.ClientOptions(
        api_endpoint=os.getenv("GOOGLE_API_BASE"),
    )
)

# %% [markdown]
# #### Pick the model that generates text

# %% [markdown]
# ```Python
# # Legacy models shown in the video
# models = [m for m in genai.list_models() if 'generateText' in m.supported_generation_methods]
# model_bison = models[0]
# # Model Bison set as legacy model in 2024
# model_bison
# ```

# %%
# Set the model to connect to the Gemini API
model_flash = genai.GenerativeModel(model_name='gemini-2.0-flash')

# %% [markdown]
# ### Legacy PaLM API
# #### Helper function to call the PaLM API
#
# ```Python
# from google.api_core import retry
# @retry.Retry()
# def generate_text(prompt,
#                   model=model_bison,
#                   temperature=0.0):
#     return palm.generate_text(prompt=prompt,
#                               model=model,
#                               temperature=temperature)
# ```

# %% [markdown]
# ### Helper function to call the Gemini API

# %%
def generate_text(prompt,
                  model=model_flash,
                  temperature=0.0):
    return model_flash.generate_content(prompt,
                                  generation_config={'temperature':temperature})

# %% [markdown]
# ### Scenario 1: Improve existing code
# - An LLM can help you rewrite your code in the way that's recommended for that particular language.
# - You can ask an LLM to rewrite your Python code in a way that is more 'Pythonic".

# %%
prompt_template = """
I don't think this code is the best way to do it in Python, can you help me?

{question}

Please explain, in detail, what you did to improve it.
"""

# %%
question = """
def func_x(array)
  for i in range(len(array)):
    print(array[i])
"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
# Gemini API
print(completion.text)

# PaLM legacy
## print(completion.result)
# Out:
# Okay, let's analyze the provided Python code and explore more Pythonic and efficient ways to achieve the same result.
#
# **Original Code:**
#
# ```python
# def func_x(array):
#   for i in range(len(array)):
#     print(array[i])
# ```
#
# **Explanation of the Original Code:**
#
# *   **`def func_x(array):`**:  This defines a function named `func_x` that takes one argument, `array`.  We assume `array` is intended to be a list or other iterable.
# *   **`for i in range(len(array)):`**: This is the core of the loop.
#     *   `len(array)`:  Calculates the number of elements in the `array`.
#     *   `range(len(array))`:  Generates a sequence of numbers from 0 up to (but not including) the length of the array.  For example, if `array` has 5 elements, `range(len(array))` will produce the sequence `0, 1, 2, 3, 4`.
#     *   `for i in ...`: The `for` loop iterates through each number in the sequence generated by `range()`.  The variable `i` takes on each of these values in turn.
# *   **`print(array[i])`**: Inside the loop, this line accesses the element at index `i` of the `array` and prints it to the console.
#
# **Why the Original Code Isn't Ideal (Not Pythonic):**
#
# The original code works, but it's not the most Pythonic or efficient way to iterate through the elements of a list (or other iterable).  Here's why:
#
# 1.  **Unnecessary Indexing:**  The code uses explicit indexing (`array[i]`) to access each element.  Python's `for` loop is designed to directly iterate over the *elements* of a sequence, rather than needing to use indices.
# 2.  **Less Readable:**  The `for i in range(len(array))` pattern is a bit verbose and less immediately clear in its intent compared to a more direct iteration.
#
# **Improved Code (Pythonic):**
#
# ```python
# def func_x(array):
#   for element in array:
#     print(element)
# ```
#
# **Explanation of the Improved Code:**
#
# *   **`def func_x(array):`**:  Same as before, defines the function.
# *   **`for element in array:`**: This is the key improvement.
#     *   `for element in array`: This directly iterates over the *elements* of the `array`.  In each iteration of the loop, the variable `element` will be assigned the value of the next element in the `array`.
# *   **`print(element)`**:  This line simply prints the current `element` to the console.
#
# **Why the Improved Code is Better:**
#
# 1.  **More Readable:** The code is much easier to understand.  It directly expresses the intent: "For each element in the array, print the element."
# 2.  **More Pythonic:** This is the standard way to iterate through elements in Python.  It's the idiom that Python developers expect and prefer.
# 3.  **Potentially More Efficient:** In some cases, iterating directly over elements can be slightly more efficient than using indexing, although the performance difference is usually negligible for simple cases.  The main benefit is readability and maintainability.
# 4.  **Works with More Iterables:** The improved code works not only with lists but also with other iterable objects like tuples, strings, sets, and dictionaries (though the order of iteration for sets and dictionaries is not guaranteed). The original code is tied to sequences that support indexing.
#
# **Example Usage:**
#
# ```python
# my_list = [1, 2, 3, 4, 5]
# func_x(my_list)  # Output: 1 2 3 4 5 (each on a new line)
#
# my_tuple = ("a", "b", "c")
# func_x(my_tuple)  # Output: a b c (each on a new line)
#
# my_string = "hello"
# func_x(my_string) # Output: h e l l o (each on a new line)
# ```
#
# **In summary:** The improved code is more Pythonic, readable, and potentially more efficient because it directly iterates over the elements of the array without relying on explicit indexing.  This is the preferred way to iterate in Python.

# %% [markdown]
# #### Ask for multiple ways of rewriting your code

# %%
prompt_template = """
I don't think this code is the best way to do it in Python, can you help me?

{question}

Please explore multiple ways of solving the problem, and explain each.
"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
print(completion.text)
# Out:
# Okay, I understand. The code you provided iterates through an array (or list in Python terminology) using an index and prints each element. While it works, it's not the most Pythonic or efficient way to achieve this. Let's explore several alternatives, ranked roughly from simplest/most common to more advanced/specialized, along with explanations:
#
# **1. The `for...in` loop (Direct Iteration):**
#
# ```python
# def func_x(array):
#   for element in array:
#     print(element)
# ```
#
# *   **Explanation:** This is the most common and generally preferred way to iterate through a list in Python.  Instead of dealing with indices, the `for` loop directly iterates over each *element* in the `array`.  This is cleaner, more readable, and often slightly faster.
#
# *   **Why it's better:**
#     *   **Readability:**  It's immediately clear that you're processing each item in the list.
#     *   **Simplicity:**  No need to manage indices.
#     *   **Less prone to errors:**  Avoids off-by-one errors that can occur when working with indices.
#
# **2. Using `enumerate` (If you need the index):**
#
# ```python
# def func_x(array):
#   for index, element in enumerate(array):
#     print(f"Index: {index}, Element: {element}")  # Or just print(element) if you don't need the index
# ```
#
# *   **Explanation:**  If you *do* need the index of each element while iterating, `enumerate` is your friend.  It returns a sequence of (index, element) tuples.
#
# *   **Why it's useful:**
#     *   **Access to both index and value:**  Sometimes you need to know the position of an element within the list (e.g., for conditional logic based on position).
#     *   **Still relatively readable:**  More readable than manual index management.
#
# **3. List Comprehension (For side effects, use with caution):**
#
# ```python
# def func_x(array):
#   [print(element) for element in array]
# ```
#
# *   **Explanation:** List comprehensions are typically used to create *new* lists based on existing ones.  However, you *can* use them to perform side effects (like printing) within the comprehension.
#
# *   **Why it's generally discouraged for printing:**
#     *   **Readability:**  List comprehensions are primarily for creating lists. Using them for side effects can make the code less clear about its intent.
#     *   **Less Pythonic:**  The `for...in` loop is the standard way to iterate and perform actions on each element.
#     *   **Potential for confusion:**  Someone reading the code might wonder why you're creating a list that you're not using.
#
# *   **When it *might* be acceptable (rare):**  If you're doing something very simple and the list comprehension is extremely concise, it *might* be acceptable.  But generally, avoid this for printing.
#
# **4. `map` (Functional Approach - also generally discouraged for printing):**
#
# ```python
# def func_x(array):
#   list(map(print, array))
# ```
#
# *   **Explanation:** The `map` function applies a given function to each item in an iterable (like a list).  In this case, it applies the `print` function to each element of the `array`.  We then convert the result of `map` to a list to force the evaluation (otherwise, `map` is a lazy iterator).
#
# *   **Why it's generally discouraged for printing:**
#     *   **Readability:**  Similar to list comprehensions, `map` is primarily for transforming data, not for side effects.
#     *   **Less Pythonic:**  The `for...in` loop is the preferred way to iterate and perform actions.
#     *   **Overly complex:**  It's more verbose than a simple `for` loop for this task.
#
# *   **When it *might* be acceptable (very rare):**  If you're already using `map` for other transformations and want to chain a printing operation, it *might* be considered.  But again, avoid this in most cases.
#
# **5. NumPy (For Numerical Arrays - if you're already using NumPy):**
#
# ```python
# import numpy as np
#
# def func_x(array):
#   np.vectorize(print)(array)
# ```
#
# *   **Explanation:** If your `array` is a NumPy array (specifically designed for numerical operations), you can use `np.vectorize` to apply the `print` function to each element.
#
# *   **Why it's useful (if you're using NumPy):**
#     *   **Potentially faster for large numerical arrays:** NumPy is optimized for numerical operations.
#     *   **Conciseness:** Can be more concise than a loop for simple operations.
#
# *   **Why it's not generally recommended:**
#     *   **Overkill if you're not using NumPy:**  NumPy has a significant overhead.  Don't use it just for printing.
#     *   **Less readable:**  The intent might not be immediately clear to someone unfamiliar with NumPy.
#
# **6. Recursion (Generally not recommended for this simple task):**
#
# ```python
# def func_x(array):
#   if not array:
#     return  # Base case: empty array
#   print(array[0])
#   func_x(array[1:])  # Recursive call with the rest of the array
# ```
#
# *   **Explanation:** This approach uses recursion.  The function prints the first element of the array and then calls itself with the rest of the array.  The base case is when the array is empty.
#
# *   **Why it's generally discouraged:**
#     *   **Inefficient:** Recursion can be less efficient than iteration in Python due to function call overhead.
#     *   **Stack overflow risk:**  For very large arrays, you could potentially exceed the maximum recursion depth.
#     *   **Less readable:**  Recursion can be harder to understand than a simple loop for this task.
#
# **Which one should you use?**
#
# *   **The `for...in` loop (Option 1) is almost always the best choice.** It's the most Pythonic, readable, and efficient way to iterate through a list and perform an action on each element.
# *   **Use `enumerate` (Option 2) if you need the index of each element.**
# *   Avoid list comprehensions, `map`, NumPy, and recursion for this simple printing task unless you have a very specific reason and understand the trade-offs.
#
# **Example of using the preferred method:**
#
# ```python
# def func_x(my_list):
#   for item in my_list:
#     print(item)
#
# # Example usage:
# my_array = [1, 2, 3, 4, 5]
# func_x(my_array)
# ```
#
# This is the cleanest, most readable, and most efficient way to print each element of a list in Python.  It's the approach you should use in almost all cases.

# %% [markdown]
# #### Paste markdown into a markdown cell
#
# If the model outputs what looks like a table in markdown, you can copy-paste markdown into a markdown cell to make it easier to view:
#
# For example:
#
# | Method | Pros | Cons |
# |---|---|---|
# | List comprehension | Concise | Can be difficult to read for complex code |
# | `enumerate()` | Easy to read | Requires an extra variable to store the index |
# | `map()` | Flexible | Requires a custom function to format the output |

# %% [markdown]
# #### Ask the model to recommend one of the methods as most 'Pythonic'

# %%
prompt_template = """
I don't think this code is the best way to do it in Python, can you help me?

{question}

Please explore multiple ways of solving the problem,
and tell me which is the most Pythonic
"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
print(completion.text)
# Out:
# Okay, let's analyze the provided code and explore more Pythonic alternatives for printing each element of an array (or, more generally, an iterable).
#
# **Original Code:**
#
# ```python
# def func_x(array):
#   for i in range(len(array)):
#     print(array[i])
# ```
#
# **Problems with the Original Code:**
#
# *   **Not Pythonic:**  The `for i in range(len(array))` pattern is a common anti-pattern in Python.  It's often a sign that you're not leveraging Python's built-in iteration capabilities.  It's more verbose and less readable than direct iteration.
# *   **Unnecessary Indexing:**  You're using the index `i` only to access the element at `array[i]`.  Python's `for` loop can directly iterate over the elements themselves.
#
# **More Pythonic Alternatives:**
#
# Here are several ways to achieve the same result, ordered from generally less to more Pythonic:
#
# 1.  **Direct Iteration (Most Pythonic):**
#
#     ```python
#     def func_x(array):
#       for element in array:
#         print(element)
#     ```
#
#     *   **Explanation:** This is the most straightforward and Pythonic way.  The `for element in array:` loop directly iterates over each element in the `array` (or any iterable), assigning it to the `element` variable in each iteration.  It's clean, readable, and efficient.
#
# 2.  **Using `enumerate` (If you need the index):**
#
#     ```python
#     def func_x(array):
#       for index, element in enumerate(array):
#         print(f"Index: {index}, Element: {element}")  # Or just print(element)
#     ```
#
#     *   **Explanation:**  The `enumerate()` function is useful when you *also* need the index of each element during iteration.  It returns a sequence of (index, element) tuples.  If you don't need the index, stick with direct iteration.
#
# 3.  **List Comprehension (For side effects, generally discouraged):**
#
#     ```python
#     def func_x(array):
#       [print(element) for element in array]
#     ```
#
#     *   **Explanation:** List comprehensions are powerful, but they are primarily designed for creating *new* lists.  Using them solely for side effects (like printing) is generally considered less readable and not their intended purpose.  While it works, it's not the best practice.
#
# 4.  **`map` (Less common for simple printing):**
#
#     ```python
#     def func_x(array):
#       list(map(print, array))  # or tuple(map(print, array))
#     ```
#
#     *   **Explanation:** The `map()` function applies a function (in this case, `print`) to each element of an iterable.  However, `map` returns a map object (an iterator), so you need to consume it (e.g., by converting it to a list or tuple) to force the `print` function to be executed for each element.  This is generally less readable than a simple `for` loop for this specific task.  Also, `map` is often used for transformations, not just side effects.
#
# **Which is the Most Pythonic?**
#
# The **most Pythonic** and generally preferred way to print each element of an array is:
#
# ```python
# def func_x(array):
#   for element in array:
#     print(element)
# ```
#
# **Why?**
#
# *   **Readability:** It's the easiest to understand at a glance.
# *   **Simplicity:** It directly expresses the intent: "For each element in the array, print it."
# *   **Efficiency:** It's generally as efficient as any other approach for this simple task.
# *   **Idiomatic:** It's the way experienced Python developers would typically write this code.
#
# **Example Usage:**
#
# ```python
# my_array = [1, 2, 3, 4, 5]
# func_x(my_array)  # Output: 1 2 3 4 5 (each on a new line)
# ```
#
# **In summary:**  Avoid using `range(len(array))` unless you absolutely need the index for some other purpose.  Embrace direct iteration for cleaner, more readable, and more Pythonic code.

# %% [markdown]
# ### Scenario 2: Simplify code
# - Ask the LLM to perform a code review.
# - Note that adding/removing newline characters may affect the LLM completion that gets output by the LLM.

# %%
# option 1
prompt_template = """
Can you please simplify this code for a linked list in Python?

{question}

Explain in detail what you did to modify it, and why.
"""

# %% [markdown]
# After you try option 1, you can modify it to look like option 2 (in this markdown cell) and see how it changes the completion.
# ```Python
# # option 2
# prompt_template = """
# Can you please simplify this code for a linked list in Python? \n
# You are an expert in Pythonic code.
#
# {question}
#
# Please comment each line in detail, \n
# and explain in detail what you did to modify it, and why.
# """
# ```

# %%
question = """
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class SLinkedList:
  def __init__(self):
    self.headval = None

list1 = SLinkedList()
list1.headval = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")
list1.headval.nextval = e2
e2.nextval = e3

"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
print(completion.text)
# Out:
# ```python
# class Node:
#   def __init__(self, data):
#     self.data = data
#     self.next = None
#
# class LinkedList:
#   def __init__(self):
#     self.head = None
#
# # Example Usage:
# linked_list = LinkedList()
# linked_list.head = Node("Mon")
# linked_list.head.next = Node("Tue")
# linked_list.head.next.next = Node("Wed")
# ```
#
# Here's a breakdown of the changes and the reasoning behind them:
#
# **1. Renaming Variables for Clarity and Consistency:**
#
# *   `dataval` in the `Node` class was changed to `data`.  This is a more common and descriptive name for the data stored within a node.  It's shorter and easier to understand at a glance.
# *   `nextval` in the `Node` class was changed to `next`.  Similar to the above, `next` is the standard and widely accepted name for the pointer to the next node in a linked list.
# *   `headval` in the `SLinkedList` class was changed to `head`.  Again, `head` is the conventional name for the first node in a linked list.  The `S` prefix in `SLinkedList` (presumably for "Singly") isn't really necessary in the class name itself, as the structure of the `Node` class already implies it's a singly linked list.  Therefore, the class name was changed to `LinkedList`.
# *   `list1` was changed to `linked_list`.  This is a more descriptive name that clearly indicates the variable holds a linked list object.
# *   `e2` and `e3` were removed.  Instead, the nodes are created directly and assigned to the `next` pointers.  This reduces the number of intermediate variables and makes the code more concise.
#
# **2. Direct Node Creation and Assignment:**
#
# Instead of creating separate `e2` and `e3` variables and then assigning them, the code now directly creates the `Node` objects and assigns them to the `next` pointers:
#
# ```python
# linked_list.head.next = Node("Tue")
# linked_list.head.next.next = Node("Wed")
# ```
#
# This approach is more concise and readable.  It avoids the need for temporary variables that only serve to hold the node objects before they are linked into the list.
#
# **3. Removed Unnecessary Comments (Implicitly):**
#
# The original code didn't have comments, but in general, well-named variables and clear code structure reduce the need for excessive commenting.  The goal is to make the code self-documenting as much as possible.
#
# **Why These Changes Are Important:**
#
# *   **Readability:**  The primary goal is to make the code easier to read and understand.  Clear variable names and a concise structure contribute significantly to readability.
# *   **Maintainability:**  Code that is easy to read is also easier to maintain.  When you or someone else needs to modify the code in the future, it will be easier to understand the existing logic and make changes without introducing errors.
# *   **Conventions:**  Using standard naming conventions (like `head` and `next`) makes the code more familiar to other Python developers, making it easier for them to collaborate or understand your code.
# *   **Conciseness:**  Reducing the number of lines of code (while maintaining readability) can make the code easier to grasp as a whole.
#
# In summary, the simplified code is more readable, maintainable, and adheres to common Python conventions for linked list implementations.  It achieves the same functionality as the original code but in a more elegant and understandable way.

# %% [markdown]
# ### Scenario 3: Write test cases
#
# - It may help to specify that you want the LLM to output "in code" to encourage it to write unit tests instead of just returning test cases in English.

# %%
prompt_template = """
Can you please create test cases in code for this Python code?

{question}

Explain in detail what these test cases are designed to achieve.
"""

# %%
# Note that the code I'm using here was output in the previous
# section. Your output code may be different.
question = """
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class SLinkedList:
  def __init__(self):
    self.head = None

def create_linked_list(data):
  head = Node(data[0])
  for i in range(1, len(data)):
    node = Node(data[i])
    node.nextval = head
    head = node
  return head

list1 = create_linked_list(["Mon", "Tue", "Wed"])
"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
print(completion.text)
# Out:
# ```python
# import unittest
#
# class Node:
#   def __init__(self, dataval=None):
#     self.dataval = dataval
#     self.nextval = None
#
# class SLinkedList:
#   def __init__(self):
#     self.head = None
#
# def create_linked_list(data):
#   head = Node(data[0])
#   for i in range(1, len(data)):
#     node = Node(data[i])
#     node.nextval = head
#     head = node
#   return head
#
#
# class TestCreateLinkedList(unittest.TestCase):
#
#     def test_empty_list(self):
#         """Test creating a linked list from an empty list."""
#         head = create_linked_list([])
#         self.assertIsNone(head)
#
#     def test_single_element_list(self):
#         """Test creating a linked list from a list with a single element."""
#         head = create_linked_list(["Mon"])
#         self.assertEqual(head.dataval, "Mon")
#         self.assertIsNone(head.nextval)
#
#     def test_multiple_elements_list(self):
#         """Test creating a linked list from a list with multiple elements."""
#         head = create_linked_list(["Mon", "Tue", "Wed"])
#         self.assertEqual(head.dataval, "Wed")
#         self.assertEqual(head.nextval.dataval, "Tue")
#         self.assertEqual(head.nextval.nextval.dataval, "Mon")
#         self.assertIsNone(head.nextval.nextval.nextval)
#
#     def test_different_data_types(self):
#         """Test creating a linked list with different data types."""
#         head = create_linked_list([1, "Tue", 3.14])
#         self.assertEqual(head.dataval, 3.14)
#         self.assertEqual(head.nextval.dataval, "Tue")
#         self.assertEqual(head.nextval.nextval.dataval, 1)
#         self.assertIsNone(head.nextval.nextval.nextval)
#
#     def test_duplicate_elements(self):
#         """Test creating a linked list with duplicate elements."""
#         head = create_linked_list(["Mon", "Tue", "Mon"])
#         self.assertEqual(head.dataval, "Mon")
#         self.assertEqual(head.nextval.dataval, "Tue")
#         self.assertEqual(head.nextval.nextval.dataval, "Mon")
#         self.assertIsNone(head.nextval.nextval.nextval)
#
#     def test_long_list(self):
#         """Test creating a linked list from a longer list to check for performance and potential errors."""
#         data = list(range(100))
#         head = create_linked_list(data)
#         current = head
#         for i in range(99, -1, -1):  # Iterate backwards as the list is created in reverse order
#             self.assertEqual(current.dataval, i)
#             current = current.nextval
#         self.assertIsNone(current)
#
#
# if __name__ == '__main__':
#     unittest.main()
# ```
#
# **Explanation of the Test Cases:**
#
# The code uses the `unittest` framework in Python to create a suite of test cases for the `create_linked_list` function.  Each test case is designed to verify a specific aspect of the function's behavior.  Here's a breakdown:
#
# 1.  **`test_empty_list(self)`:**
#     *   **Purpose:**  This test checks what happens when you try to create a linked list from an empty list (`[]`).
#     *   **Expected Behavior:** The function should return `None` because there are no elements to create nodes from.  An empty list should result in an empty linked list (represented by a `None` head).
#
# 2.  **`test_single_element_list(self)`:**
#     *   **Purpose:** This test verifies the function's behavior when given a list containing only one element.
#     *   **Expected Behavior:** The function should create a linked list with a single node. The `dataval` of the head node should be the element from the input list, and the `nextval` of the head node should be `None` (because it's the end of the list).
#
# 3.  **`test_multiple_elements_list(self)`:**
#     *   **Purpose:** This is the core test case. It checks the function's ability to create a linked list from a list with multiple elements.  It specifically tests the order of elements in the linked list.
#     *   **Expected Behavior:** The function should create a linked list where the elements are in *reverse* order compared to the input list. This is because the `create_linked_list` function prepends each new node to the head.  The test asserts that the `dataval` of each node is correct and that the `nextval` pointers are set up correctly to link the nodes together.  It also verifies that the last node's `nextval` is `None`.
#
# 4.  **`test_different_data_types(self)`:**
#     *   **Purpose:** This test ensures that the function can handle lists containing elements of different data types (integers, strings, floats, etc.).
#     *   **Expected Behavior:** The function should correctly create the linked list, storing the different data types in the `dataval` of the nodes.  The order should still be reversed.
#
# 5.  **`test_duplicate_elements(self)`:**
#     *   **Purpose:** This test checks if the function correctly handles lists that contain duplicate elements.
#     *   **Expected Behavior:** The function should create the linked list without any issues, even if some elements are repeated. The order and values should still be correct.
#
# 6.  **`test_long_list(self)`:**
#     *   **Purpose:** This test is designed to check the function's performance and stability when dealing with a larger list. It helps identify potential issues like stack overflow errors or performance bottlenecks that might only appear with larger datasets.
#     *   **Expected Behavior:** The function should create the linked list correctly, even with 100 elements. The test iterates through the created linked list and verifies that each node contains the correct data in the expected (reversed) order.
#
# **How to Run the Tests:**
#
# 1.  **Save the code:** Save the code as a Python file (e.g., `linked_list_test.py`).
# 2.  **Run from the command line:** Open a terminal or command prompt, navigate to the directory where you saved the file, and run the command:
#
#     ```bash
#     python -m unittest linked_list_test.py
#     ```
#
# The `unittest` framework will execute the test cases and report the results (whether each test passed or failed).
#
# **Key Concepts Illustrated by the Tests:**
#
# *   **Edge Cases:** The `test_empty_list` and `test_single_element_list` tests cover edge cases, which are often overlooked but important to handle correctly.
# *   **Data Type Handling:** The `test_different_data_types` test demonstrates the importance of writing code that can handle various data types.
# *   **Order of Elements:** The `test_multiple_elements_list` test specifically verifies the order of elements in the created linked list, which is crucial for the function's correctness.
# *   **Scalability:** The `test_long_list` test addresses the scalability of the function, ensuring it can handle larger datasets without issues.
# *   **Reverse Order Creation:** The tests are designed to account for the fact that the `create_linked_list` function builds the list in reverse order by prepending new nodes to the head.
#
# These test cases provide a comprehensive set of checks to ensure that the `create_linked_list` function is working correctly and robustly.  They cover various scenarios and potential edge cases, making the code more reliable.

# %% [markdown]
# ### Scenario 4: Make code more efficient
# - Improve runtime by potentially avoiding inefficient methods (such as ones that use recursion when not needed).

# %%
prompt_template = """
Can you please make this code more efficient?

{question}

Explain in detail what you changed and why.
"""

# %%
question = """
# Returns index of x in arr if present, else -1
def binary_search(arr, low, high, x):
    # Check base case
    if high >= low:
        mid = (high + low) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

# Test array
arr = [ 2, 3, 4, 10, 40 ]
x = 10

# Function call
result = binary_search(arr, 0, len(arr)-1, x)

if result != -1:
    print("Element is present at index", str(result))
else:
    print("Element is not present in array")

"""

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question)
)
print(completion.text)
# Out:
# ```python
# # Returns index of x in arr if present, else -1
# def binary_search(arr, low, high, x):
#     """
#     Performs binary search on a sorted array.
#
#     Args:
#         arr: The sorted array to search.
#         low: The starting index of the search range.
#         high: The ending index of the search range.
#         x: The element to search for.
#
#     Returns:
#         The index of x in arr if present, else -1.
#     """
#     while low <= high:
#         mid = low + (high - low) // 2  # Prevent potential overflow
#         if arr[mid] == x:
#             return mid
#         elif arr[mid] < x:
#             low = mid + 1
#         else:
#             high = mid - 1
#     return -1
#
# # Test array
# arr = [ 2, 3, 4, 10, 40 ]
# x = 10
#
# # Function call
# result = binary_search(arr, 0, len(arr)-1, x)
#
# if result != -1:
#     print("Element is present at index", str(result))
# else:
#     print("Element is not present in array")
# ```
#
# Here's a breakdown of the changes and the reasoning behind them:
#
# **1. Iterative Approach Instead of Recursion:**
#
# *   **Original Code:** The original code used a recursive implementation of binary search.  Recursion involves function calls, which have overhead associated with them (stack management, function call setup/teardown).  For large arrays, this overhead can become significant.
# *   **Improved Code:** The improved code uses an iterative (loop-based) approach.  Iterative solutions generally have better performance than recursive solutions for problems like binary search because they avoid the function call overhead.
#
# **Why Iteration is More Efficient:**
#
# *   **Reduced Overhead:** Iteration avoids the overhead of function calls, making it faster, especially for large datasets.
# *   **Stack Overflow Prevention:**  Deep recursion can lead to stack overflow errors if the recursion depth exceeds the stack size limit. Iteration doesn't have this problem.
#
# **2. Overflow Prevention in Midpoint Calculation:**
#
# *   **Original Code:** `mid = (high + low) // 2`
# *   **Improved Code:** `mid = low + (high - low) // 2`
#
# **Why Overflow Prevention is Important:**
#
# *   **Potential Integer Overflow:** In some languages (like Java or C++), if `high` and `low` are very large numbers, their sum `(high + low)` could exceed the maximum value that an integer variable can hold. This leads to an integer overflow, resulting in a negative or unexpected value for `mid`.  While Python handles large integers automatically, it's a good practice to write code that is robust and avoids potential overflow issues, especially if you might port the code to another language.
# *   **Safer Calculation:** The expression `low + (high - low) // 2` is mathematically equivalent to `(high + low) // 2`, but it avoids the potential overflow.  It calculates the difference between `high` and `low` first, which is guaranteed to be within the valid integer range, and then adds it to `low`.
#
# **In summary:**
#
# The iterative approach eliminates function call overhead, making the binary search significantly faster, especially for large arrays. The overflow prevention in the midpoint calculation makes the code more robust and less prone to errors in languages with fixed-size integers.  These changes improve both the performance and the reliability of the binary search algorithm.

# %% [markdown]
# #### Try out the LLM-generated code
# - If it uses `bisect`, you may first need to `import bisect`
# - Remember to check what the generated code is actually doing.  For instance, the code may work because it is calling a predefined function (such as `bisect`), even though the rest of the code is technically broken.

# %%
# Paste the LLM-generated code to inspect and debug it

# %% [markdown]
# ### Scenario 5: Debug your code

# %%
prompt_template = """
Can you please help me to debug this code?

{question}

Explain in detail what you found and why it was a bug.
"""

# %%
# I deliberately introduced a bug into this code! Let's see if the LLM can find it.
# Note -- the model can't see this comment -- but the bug is in the
# print function. There's a circumstance where nodes can be null, and trying
# to print them would give a null error.
question = """
class Node:
   def __init__(self, data):
      self.data = data
      self.next = None
      self.prev = None

class doubly_linked_list:
   def __init__(self):
      self.head = None

# Adding data elements
   def push(self, NewVal):
      NewNode = Node(NewVal)
      NewNode.next = self.head
      if self.head is not None:
         self.head.prev = NewNode
      self.head = NewNode

# Print the Doubly Linked list in order
   def listprint(self, node):
       print(node.data),
       last = node
       node = node.next

dllist = doubly_linked_list()
dllist.push(12)
dllist.push(8)
dllist.push(62)
dllist.listprint(dllist.head)

"""

# %% [markdown]
# Notice in this case that we are using the default temperature of `0.7` to generate the example that you're seeing in the lecture video.
# - Since a temperature > 0 encourages more randomness in the LLM output, you may want to run this code a couple times to see what it outputs.

# %%
completion = generate_text(
    prompt = prompt_template.format(question=question),
    temperature = 0.7
)
print(completion.text)
# Out:
# Okay, let's analyze the provided Python code for a doubly linked list and identify the bug.
#
# **Code:**
#
# ```python
# class Node:
#    def __init__(self, data):
#       self.data = data
#       self.next = None
#       self.prev = None
#
# class doubly_linked_list:
#    def __init__(self):
#       self.head = None
#
# # Adding data elements
#    def push(self, NewVal):
#       NewNode = Node(NewVal)
#       NewNode.next = self.head
#       if self.head is not None:
#          self.head.prev = NewNode
#       self.head = NewNode
#
# # Print the Doubly Linked list in order
#    def listprint(self, node):
#        print(node.data),  # Python 2 syntax for print without newline
#        last = node
#        node = node.next
#
# dllist = doubly_linked_list()
# dllist.push(12)
# dllist.push(8)
# dllist.push(62)
# dllist.listprint(dllist.head)
# ```
#
# **Identifying the Bug**
#
# The `listprint` function has a bug that causes it to print only the first element of the doubly linked list. The root cause is the function does not iterate through the list.
#
# **Explanation:**
#
# 1.  **One-Time Print:** The `listprint` function is designed to print the data of a node and then move to the next node. However, it only executes these steps *once*.  It prints the data of the initial `node` (which is `dllist.head` in the main part of the code), assigns `node` to the `last` variable, and then sets `node` to `node.next`.  The function then ends.  There is no loop to continue printing subsequent nodes.
#
# 2.  **Missing Loop:**  To print the entire list, you need a loop that continues as long as there are more nodes to print (i.e., as long as `node` is not `None`).
#
# 3.  **Python 2 `print` syntax:** The original code uses Python 2 `print` syntax (`print node.data,`).  This syntax prevents a newline character from being printed after each element.  While this isn't a bug *per se*, it's worth noting that in Python 3, the `print` function requires parentheses: `print(node.data, end=" ")` to achieve the same effect of printing without a newline. I will change the code to be python 3 compatible.
#
# **Corrected Code**
#
# Here's the corrected `listprint` function with a `while` loop to iterate through the entire list:
#
# ```python
# class Node:
#    def __init__(self, data):
#       self.data = data
#       self.next = None
#       self.prev = None
#
# class doubly_linked_list:
#    def __init__(self):
#       self.head = None
#
# # Adding data elements
#    def push(self, NewVal):
#       NewNode = Node(NewVal)
#       NewNode.next = self.head
#       if self.head is not None:
#          self.head.prev = NewNode
#       self.head = NewNode
#
# # Print the Doubly Linked list in order
#    def listprint(self, node):
#         while (node is not None):
#             print(node.data, end=" ")  # Python 3 syntax for print without newline
#             last = node
#             node = node.next
#         print()  # Add a newline at the end of the list
#
# dllist = doubly_linked_list()
# dllist.push(12)
# dllist.push(8)
# dllist.push(62)
# dllist.listprint(dllist.head)
# ```
#
# **Explanation of Corrections:**
#
# 1.  **`while (node is not None):`**: This loop continues as long as the `node` variable is not `None`.  `node` becomes `None` when you reach the end of the list (the `next` pointer of the last node is `None`).
#
# 2.  **`print(node.data, end=" ")`**:  This line prints the data of the current node, followed by a space, but no newline.  This keeps all the elements on the same line. The syntax is now Python 3 compatible.
#
# 3.  **`print()`**: After the loop finishes, this line prints a newline character to move the cursor to the next line in the console.
#
# **How the Corrected Code Works**
#
# 1.  The `listprint` function receives the `head` of the list as input.
# 2.  The `while` loop starts.
# 3.  Inside the loop:
#     *   The data of the current `node` is printed.
#     *   `last` is updated to store the current `node`.
#     *   `node` is updated to point to the next node in the list (`node.next`).
# 4.  The loop continues until `node` becomes `None`, indicating the end of the list.
# 5.  Finally, a newline is printed to format the output.
#
# Now, the corrected code will print all the elements of the doubly linked list in the correct order.

# %% [markdown]
# #### Reminder to check the code
# You can use an  LLM to give you insights and check for blind spots, but remember to check that the generated code is doing what you want it to do.
